# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
# %matplotlib inline

# %%
data = pd.read_csv('cleaned_1.csv')
data.head()
# Out:
#    Unnamed: 0  srch_id            date_time  site_id  \
# 0           0        1  2013-04-04 08:32:15       12
# 1           1        1  2013-04-04 08:32:15       12
# 2           2        1  2013-04-04 08:32:15       12
# 3           3        1  2013-04-04 08:32:15       12
# 4           4        1  2013-04-04 08:32:15       12
#
#    visitor_location_country_id  prop_country_id  prop_id  prop_starrating  \
# 0                          187              219      893                3
# 1                          187              219    10404                4
# 2                          187              219    21315                3
# 3                          187              219    27348                2
# 4                          187              219    29604                4
#
#    prop_review_score  prop_brand_bool      ...       srch_destination_id  \
# 0                3.5                1      ...                     23246
# ...

# %%
data = data.drop(data.columns[[0,1]],axis = 1)
data.head()
# Out:
#              date_time  site_id  visitor_location_country_id  prop_country_id  \
# 0  2013-04-04 08:32:15       12                          187              219
# 1  2013-04-04 08:32:15       12                          187              219
# 2  2013-04-04 08:32:15       12                          187              219
# 3  2013-04-04 08:32:15       12                          187              219
# 4  2013-04-04 08:32:15       12                          187              219
#
#    prop_id  prop_starrating  prop_review_score  prop_brand_bool  \
# 0      893                3                3.5                1
# 1    10404                4                4.0                1
# 2    21315                3                4.5                1
# 3    27348                2                4.0                1
# 4    29604                4                3.5                1
#
#    prop_location_score1  prop_log_historical_price      ...       \
# ...

# %%
#data['date_time'] = pd.to_datetime(data['date_time'], format = '%Y-%m-%d %H:%M:%S')
#data.dtypes

# %%
temp = pd.DatetimeIndex(data['date_time'])
data.insert(loc=1,column='search_year',value=temp.year)
data.insert(loc=2,column='search_month',value=temp.month)
data.insert(loc=3,column='search_day',value=temp.day)
data.insert(loc=4,column='search_dayofweek',value=temp.dayofweek)
data.head()
# Out:
#              date_time  search_year  search_month  search_day  \
# 0  2013-04-04 08:32:15         2013             4           4
# 1  2013-04-04 08:32:15         2013             4           4
# 2  2013-04-04 08:32:15         2013             4           4
# 3  2013-04-04 08:32:15         2013             4           4
# 4  2013-04-04 08:32:15         2013             4           4
#
#    search_dayofweek  site_id  visitor_location_country_id  prop_country_id  \
# 0                 3       12                          187              219
# 1                 3       12                          187              219
# 2                 3       12                          187              219
# 3                 3       12                          187              219
# 4                 3       12                          187              219
#
#    prop_id  prop_starrating      ...       srch_destination_id  \
# 0      893                3      ...                     23246
# ...

# %%
data.groupby('site_id').count()
# Out:
#          date_time  search_year  search_month  search_day  search_dayofweek  \
# site_id
# 1            22298        22298         22298       22298             22298
# 2            11875        11875         11875       11875             11875
# 3             7015         7015          7015        7015              7015
# 4            27243        27243         27243       27243             27243
# 5          6164803      6164803       6164803     6164803           6164803
# 6             4807         4807          4807        4807              4807
# 7            64157        64157         64157       64157             64157
# 8               62           62            62          62                62
# 9            82298        82298         82298       82298             82298
# 10           19346        19346         19346       19346             19346
# 11           69698        69698         69698       69698             69698
# ...

# %%
data.groupby('prop_id').count()
# Out:
#          date_time  search_year  search_month  search_day  search_dayofweek  \
# prop_id
# 1              123          123           123         123               123
# 2               29           29            29          29                29
# 3              172          172           172         172               172
# 4               42           42            42          42                42
# 5               52           52            52          52                52
# 6               17           17            17          17                17
# 7               14           14            14          14                14
# 8                9            9             9           9                 9
# 9               26           26            26          26                26
# 10               9            9             9           9                 9
# 11             242          242           242         242               242
# ...

# %%
# Group values for Series and add 'cnt' column with count
data['hotel_cnt'] = data.groupby(['prop_id'])['date_time'].transform('count')
# Drop indexes for count value < 100, and dropping 'cnt' column
new_data = data.drop(data[data.hotel_cnt < 100].index)[data.columns]

# %%
new_data.shape
# Out:
# (7378466, 28)

# %%
new_data.columns
# Out:
# Index(['date_time', 'search_year', 'search_month', 'search_day',
#        'search_dayofweek', 'site_id', 'visitor_location_country_id',
#        'prop_country_id', 'prop_id', 'prop_starrating', 'prop_review_score',
#        'prop_brand_bool', 'prop_location_score1', 'prop_log_historical_price',
#        'position', 'price_usd', 'promotion_flag', 'srch_destination_id',
#        'srch_length_of_stay', 'srch_booking_window', 'srch_adults_count',
#        'srch_children_count', 'srch_room_count', 'srch_saturday_night_bool',
#        'random_bool', 'click_bool', 'booking_bool', 'hotel_cnt'],
#       dtype='object')

# %%
data.groupby('prop_id').count()
# Out:
#          date_time  search_year  search_month  search_day  search_dayofweek  \
# prop_id
# 1              123          123           123         123               123
# 3              172          172           172         172               172
# 11             242          242           242         242               242
# 15             170          170           170         170               170
# 16             101          101           101         101               101
# 17             108          108           108         108               108
# 33             287          287           287         287               287
# 37             127          127           127         127               127
# 38             128          128           128         128               128
# 56             225          225           225         225               225
# 63             126          126           126         126               126
# ...

# %%
new_data = data.drop(data[data.hotel_cnt < 500].index)[data.columns]

# %%
new_data.shape
# Out:
# (2460472, 28)

# %%
data.groupby('prop_id').count()
# Out:
#          date_time  search_year  search_month  search_day  search_dayofweek  \
# prop_id
# 109            516          516           516         516               516
# 149            804          804           804         804               804
# 162            559          559           559         559               559
# 208            761          761           761         761               761
# 269            505          505           505         505               505
# 361            986          986           986         986               986
# 372            545          545           545         545               545
# 419           1331         1331          1331        1331              1331
# 442            567          567           567         567               567
# 453            583          583           583         583               583
# 537            632          632           632         632               632
# ...

# %%
new_data = data.drop(data[data.hotel_cnt < 1000].index)[data.columns]
new_data.shape
# Out:
# (960265, 28)

# %%
data.groupby('prop_id').count()
# Out:
#          date_time  search_year  search_month  search_day  search_dayofweek  \
# prop_id
# 419           1331         1331          1331        1331              1331
# 560           1281         1281          1281        1281              1281
# 893           1237         1237          1237        1237              1237
# 978           1212         1212          1212        1212              1212
# 1230          3378         3378          3378        3378              3378
# 1497          2120         2120          2120        2120              2120
# 1535          1100         1100          1100        1100              1100
# 2906          1663         1663          1663        1663              1663
# 3046          1201         1201          1201        1201              1201
# 3213          3233         3233          3233        3233              3233
# 3235          1094         1094          1094        1094              1094
# ...

# %%
new_data.to_csv('cleaned_2.csv')
